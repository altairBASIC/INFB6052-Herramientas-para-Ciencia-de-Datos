# %% [markdown]
# # Tarea: Mapa paralelo — Comparación de herramientas (Comercial vs Open Source)
# **Curso: HERRAMIENTAS PARA CIENCIA DE DATOS**
# **Integrantes:**
# **Profesor(a): MICHAEL GABRIEL MIRANDA SANDOVAL**
# **Fecha de entrega: 05-11-2025**

# %% [markdown]
# ## 1. Introducción y Objetivo

# %% [markdown]
# ## Resumen ejecutivo

# %% [markdown]
# ## 2. Selección de Herramientas

# %% [markdown]
# ## 4. Ejemplo de Uso: Herramienta Comercial

# %% [markdown]
# ## 5. Ejemplo de Uso: Herramienta Open Source

# %% [markdown]
# ## 6. Comparación de las Herramientas

# %% [markdown]
# ### Tabla comparativa

# %% [markdown]
# ## Conclusiones y Reflexión

# %% [markdown]
# ## Referencias
